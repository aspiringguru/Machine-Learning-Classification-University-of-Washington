# %% [markdown]
# # Exploring Ensemble Methods

# %% [markdown]
# In this assignment, we will explore the use of boosting. We will use the pre-implemented gradient boosted trees in GraphLab Create. You will:
#
# * Use SFrames to do some feature engineering.
# * Train a boosted ensemble of decision-trees (gradient boosted trees) on the LendingClub dataset.
# * Predict whether a loan will default along with prediction probabilities (on a validation set).
# * Evaluate the trained model and compare it with a baseline.
# * Find the most positive and negative loans using the learned model.
# * Explore how the number of trees influences classification performance.
#
# Let's get started!
#
# ## Fire up Graphlab Create

# %%
import graphlab
import time
print "libraries loaded"
# Out:
# libraries loaded

# %% [markdown]
# # Load LendingClub dataset
#
# We will be using the [LendingClub](https://www.lendingclub.com/) data. As discussed earlier, the [LendingClub](https://www.lendingclub.com/) is a peer-to-peer leading company that directly connects borrowers and potential lenders/investors.
#
# Just like we did in previous assignments, we will build a classification model to predict whether or not a loan provided by lending club is likely to default.
#
# Let us start by loading the data.

# %%
loans = graphlab.SFrame('../data/lending-club-data.gl/')
print loans.shape
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to bmatthewtaylor@gmail.com and will expire on October 27, 2017.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\username\AppData\Local\Temp\graphlab_server_1485992621.log.0
# (122607, 68)

# %% [markdown]
# Let's quickly explore what the dataset looks like. First, let's print out the column names to see what features we have in this dataset. We have done this in previous assignments, so we won't belabor this here.

# %%
loans.column_names()
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'is_inc_v',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'not_compliant',
#  'status',
# ...

# %% [markdown]
# ## Modifying the target column
#
# The target column (label column) of the dataset that we are interested in is called `bad_loans`. In this column **1** means a risky (bad) loan **0** means a safe  loan.
#
# As in past assignments, in order to make this more intuitive and consistent with the lectures, we reassign the target to be:
# * **+1** as a safe  loan,
# * **-1** as a risky (bad) loan.
#
# We put this in a new column called `safe_loans`.

# %%
print "before # of columns = ", len(loans.column_names())
loans['safe_loans'] = loans['bad_loans'].apply(lambda x : +1 if x==0 else -1)
loans = loans.remove_column('bad_loans')
print "after # of columns = ", len(loans.column_names())
# Out:
# before # of columns =  68
# after # of columns =  68

# %% [markdown]
# ## Selecting features
#
# In this assignment, we will be using a subset of features (categorical and numeric). The features we will be using are **described in the code comments** below. If you are a finance geek, the [LendingClub](https://www.lendingclub.com/) website has a lot more details about these features.
#
# The features we will be using are described in the code comments below:

# %%
target = 'safe_loans'
features = ['grade',                     # grade of the loan (categorical)
            'sub_grade_num',             # sub-grade of the loan as a number from 0 to 1
            'short_emp',                 # one year or less of employment
            'emp_length_num',            # number of years of employment
            'home_ownership',            # home_ownership status: own, mortgage or rent
            'dti',                       # debt to income ratio
            'purpose',                   # the purpose of the loan
            'payment_inc_ratio',         # ratio of the monthly payment to income
            'delinq_2yrs',               # number of delinquincies 
            'delinq_2yrs_zero',          # no delinquincies in last 2 years
            'inq_last_6mths',            # number of creditor inquiries in last 6 months
            'last_delinq_none',          # has borrower had a delinquincy
            'last_major_derog_none',     # has borrower had 90 day or worse rating
            'open_acc',                  # number of open credit accounts
            'pub_rec',                   # number of derogatory public records
            'pub_rec_zero',              # no derogatory public records
            'revol_util',                # percent of available credit being used
            'total_rec_late_fee',        # total late fees received to day
            'int_rate',                  # interest rate of the loan
            'total_rec_int',             # interest received to date
            'annual_inc',                # annual income of borrower
            'funded_amnt',               # amount committed to the loan
            'funded_amnt_inv',           # amount committed by investors for the loan
            'installment',               # monthly payment owed by the borrower
           ]
print len(features)
# Out:
# 24

# %% [markdown]
# ## Skipping observations with missing values
#
# Recall from the lectures that one common approach to coping with missing values is to **skip** observations that contain missing values.
#
# We run the following code to do so:

# %%
print "type(loans) = ", type(loans)
loans, loans_with_na = loans[[target] + features].dropna_split()
print "type(loans) = ", type(loans)
print "type(loans_with_na)= ", type(loans_with_na)
#https://turi.com/products/create/docs/generated/graphlab.SFrame.dropna_split.html
print "loans.shape = ", loans.shape
print "loans_with_na.shape = ", loans_with_na.shape

# Count the number of rows with missing data
num_rows_with_na = loans_with_na.num_rows()
num_rows = loans.num_rows()
print 'Dropping %s observations; keeping %s ' % (num_rows_with_na, num_rows)
# Out:
# type(loans) =  <class 'graphlab.data_structures.sframe.SFrame'>
# type(loans) =  <class 'graphlab.data_structures.sframe.SFrame'>
# type(loans_with_na)=  <class 'graphlab.data_structures.sframe.SFrame'>
# loans.shape =  (122578, 25)
# loans_with_na.shape =  (29, 25)
# Dropping 29 observations; keeping 122578

# %% [markdown]
# Fortunately, there are not too many missing values. We are retaining most of the data.

# %% [markdown]
# ## Make sure the classes are balanced

# %% [markdown]
# We saw in an earlier assignment that this dataset is also imbalanced. We will undersample the larger class (safe loans) in order to balance out our dataset. We used `seed=1` to make sure everyone gets the same results.

# %%
safe_loans_raw = loans[loans[target] == 1]
risky_loans_raw = loans[loans[target] == -1]
print "before undersampling. "
print "number of safe_loans_raw                 :", safe_loans_raw.shape[0]
print "number of risky_loans_raw                :", risky_loans_raw.shape[0]
print "Percentage of safe loans                 :", len(safe_loans_raw) / float(len(safe_loans_raw)+len(risky_loans_raw) )
print "Percentage of risky loans                :", len(risky_loans_raw) / float(len(risky_loans_raw)+len(safe_loans_raw) )
print "Total number of loans                    :", len(safe_loans_raw) + len(risky_loans_raw)
print "_______________________________________________________________________________________"

# Undersample the safe loans.
percentage = len(risky_loans_raw)/float(len(safe_loans_raw))
safe_loans = safe_loans_raw.sample(percentage, seed = 1)
risky_loans = risky_loans_raw
loans_data = risky_loans.append(safe_loans)
print "after undersampling. "
print "number of safe_loans                     :", safe_loans.shape[0]
print "number of risky_loans                    :", risky_loans.shape[0]
print "Percentage of safe loans                 :", len(safe_loans) / float(len(loans_data))
print "Percentage of risky loans                :", len(risky_loans) / float(len(loans_data))
print "Total number of loans in our new dataset :", len(loans_data)
# Out:
# before undersampling.
# number of safe_loans_raw                 : 99431
# number of risky_loans_raw                : 23147
# Percentage of safe loans                 : 0.811165135669
# Percentage of risky loans                : 0.188834864331
# Total number of loans                    : 122578
# _______________________________________________________________________________________
# after undersampling.
# number of safe_loans                     : 23356
# number of risky_loans                    : 23147
# Percentage of safe loans                 : 0.502247166849
# Percentage of risky loans                : 0.497752833151
# Total number of loans in our new dataset : 46503

# %% [markdown]
# **Checkpoint:** You should now see that the dataset is balanced (approximately 50-50 safe vs risky loans).

# %% [markdown]
# **Note:** There are many approaches for dealing with imbalanced data, including some where we modify the learning algorithm. These approaches are beyond the scope of this course, but some of them are reviewed in this [paper](http://ieeexplore.ieee.org/xpl/login.jsp?tp=&arnumber=5128907&url=http%3A%2F%2Fieeexplore.ieee.org%2Fiel5%2F69%2F5173046%2F05128907.pdf%3Farnumber%3D5128907 ). For this assignment, we use the simplest possible approach, where we subsample the overly represented class to get a more balanced dataset. In general, and especially when the data is highly imbalanced, we recommend using more advanced methods.

# %% [markdown]
# ## Split data into training and validation sets

# %% [markdown]
# We split the data into training data and validation data. We used `seed=1` to make sure everyone gets the same results. We will use the validation data to help us select model parameters.

# %%
train_data, validation_data = loans_data.random_split(.8, seed=1)
print "train_data.shape = ", train_data.shape
print "validation_data.shape = ", validation_data.shape
# Out:
# train_data.shape =  (37219, 25)
# validation_data.shape =  (9284, 25)

# %% [markdown]
# # Gradient boosted tree classifier

# %% [markdown]
# Gradient boosted trees are a powerful variant of boosting methods; they have been used to win many [Kaggle](https://www.kaggle.com/) competitions, and have been widely used in industry.  We will explore the predictive power of multiple decision trees as opposed to a single decision tree.
#
# **Additional reading:** If you are interested in gradient boosted trees, here is some additional reading material:
# * [GraphLab Create user guide](https://dato.com/learn/userguide/supervised-learning/boosted_trees_classifier.html)
# * [Advanced material on boosted trees](http://homes.cs.washington.edu/~tqchen/pdf/BoostedTree.pdf)
#
#
# We will now train models to predict `safe_loans` using the features above. In this section, we will experiment with training an ensemble of 5 trees. To cap the ensemble classifier at 5 trees, we call the function with **max_iterations=5** (recall that each iterations corresponds to adding a tree). We set `validation_set=None` to make sure everyone gets the same results.

# %%
model_5 = graphlab.boosted_trees_classifier.create(train_data, 
                                                   validation_set=None, 
                                                   target = target, 
                                                   features = features, 
                                                   max_iterations = 5)
#https://turi.com/products/create/docs/generated/graphlab.boosted_trees_classifier.BoostedTreesClassifier.html
#https://turi.com/products/create/docs/generated/graphlab.boosted_trees_regression.BoostedTreesRegression.html
#https://turi.com/learn/userguide/supervised-learning/boosted_trees_classifier.html
#
print "type(model_5) = ", type(model_5)
# Out:
# Boosted trees classifier:
# --------------------------------------------------------
# Number of examples          : 37219
# Number of classes           : 2
# Number of feature columns   : 24
# Number of unpacked features : 24
# +-----------+--------------+-------------------+-------------------+
# | Iteration | Elapsed Time | Training-accuracy | Training-log_loss |
# +-----------+--------------+-------------------+-------------------+
# | 1         | 0.078557     | 0.657541          | 0.657139          |
# | 2         | 0.144615     | 0.656976          | 0.636157          |
# | 3         | 0.212176     | 0.664983          | 0.623206          |
# | 4         | 0.278736     | 0.668476          | 0.613783          |
# | 5         | 0.343294     | 0.673339          | 0.606229          |
# +-----------+--------------+-------------------+-------------------+
# type(model_5) =  <class 'graphlab.toolkits.classifier.boosted_trees_classifier.BoostedTreesClassifier'>

# %% [markdown]
# # Making predictions
#
# Just like we did in previous sections, let us consider a few positive and negative examples **from the validation set**. We will do the following:
# * Predict whether or not a loan is likely to default.
# * Predict the probability with which the loan is likely to default.

# %%
# Select all positive and negative examples.
validation_safe_loans = validation_data[validation_data[target] == 1]
validation_risky_loans = validation_data[validation_data[target] == -1]
#NB: validation data is roughly 50-50
#
#print "validation_safe_loans.shape = ", validation_safe_loans.shape
#print "validation_risky_loans.shape = ", validation_risky_loans.shape

print "number of validation_safe_loans          :", validation_safe_loans.shape[0]
print "number of validation_risky_loans         :", validation_risky_loans.shape[0]
print "Percentage of safe loans                 :", round(len(validation_safe_loans) /  float(len(validation_risky_loans)+len(validation_safe_loans))*100, 2)
print "Percentage of risky loans                :", round(len(validation_risky_loans) / float(len(validation_risky_loans)+len(validation_safe_loans))*100, 2)
print "Total # of loans in validation dataset   :", len(validation_risky_loans)+len(validation_safe_loans)



# Select 2 examples from the validation set for positive & negative loans
sample_validation_data_risky = validation_risky_loans[0:2]
sample_validation_data_safe = validation_safe_loans[0:2]
#


# Append the 4 examples into a single dataset
sample_validation_data = sample_validation_data_safe.append(sample_validation_data_risky)
sample_validation_data
# Out:
# number of validation_safe_loans          : 4612
# number of validation_risky_loans         : 4672
# Percentage of safe loans                 : 49.68
# Percentage of risky loans                : 50.32
# Total # of loans in validation dataset   : 9284
# Columns:
# 	safe_loans	int
# 	grade	str
# 	sub_grade_num	float
# 	short_emp	int
# 	emp_length_num	int
# 	home_ownership	str
# 	dti	float
# 	purpose	str
# 	payment_inc_ratio	float
# 	delinq_2yrs	int
# 	delinq_2yrs_zero	int
# 	inq_last_6mths	int
# 	last_delinq_none	int
# 	last_major_derog_none	int
# 	open_acc	int
# 	pub_rec	int
# 	pub_rec_zero	int
# 	revol_util	float
# 	total_rec_late_fee	float
# 	int_rate	float
# 	total_rec_int	float
# 	annual_inc	int
# 	funded_amnt	int
# 	funded_amnt_inv	int
# 	installment	float
#
# Rows: 4
#
# Data:
# +------------+-------+---------------+-----------+----------------+----------------+
# | safe_loans | grade | sub_grade_num | short_emp | emp_length_num | home_ownership |
# ...

# %% [markdown]
# ### Predicting on sample validation data
#
# For each row in the **sample_validation_data**, write code to make **model_5** predict whether or not the loan is classified as a **safe loan**.
#
# **Hint:** Use the `predict` method in `model_5` for this.

# %%
print "type(sample_validation_data) = ", type(sample_validation_data)
print "type(model_5) = ", type(model_5)
#https://turi.com/products/create/docs/generated/graphlab.boosted_trees_classifier.BoostedTreesClassifier.predict.html#graphlab.boosted_trees_classifier.BoostedTreesClassifier.predict
#BoostedTreesClassifier.predict(dataset, output_type='class', missing_value_action='auto')
start = time.time()
predictions = model_5.predict(sample_validation_data)
end = time.time()
print "time to predict = ", round(end-start, 4), " seconds"
print "type(predictions) = ", type(predictions)
print "type(sample_validation_data['safe_loans']) = ", type(sample_validation_data['safe_loans'])
print predictions.shape
print sample_validation_data['safe_loans']
print predictions
print "prediction accuracy = ", sum(sample_validation_data['safe_loans']==predictions)/float(len(predictions))
# Out:
# type(sample_validation_data) =  <class 'graphlab.data_structures.sframe.SFrame'>
# type(model_5) =  <class 'graphlab.toolkits.classifier.boosted_trees_classifier.BoostedTreesClassifier'>
# time to predict =  0.016  seconds
# type(predictions) =  <class 'graphlab.data_structures.sarray.SArray'>
# type(sample_validation_data['safe_loans']) =  <class 'graphlab.data_structures.sarray.SArray'>
# (4,)
# [1L, 1L, -1L, -1L]
# [1L, 1L, -1L, 1L]
# prediction accuracy =  0.75

# %% [markdown]
# **Quiz Question 1:** What percentage of the predictions on `sample_validation_data` did `model_5` get correct?
#
# ### Prediction probabilities

# %%
#print "(Quiz Q2 answer) prediction accuracy = ", sum(sample_validation_data['safe_loans']==predictions)/float(len(predictions))

# %% [markdown]
# For each row in the **sample_validation_data**, what is the probability (according **model_5**) of a loan being classified as **safe**?
#
# **Hint:** Set `output_type='probability'` to make **probability** predictions using `model_5` on `sample_validation_data`:

# %%
predictedProbability = model_5.predict(sample_validation_data, output_type='probability')
#https://turi.com/products/create/docs/generated/graphlab.boosted_trees_classifier.BoostedTreesClassifier.predict.html#graphlab.boosted_trees_classifier.BoostedTreesClassifier.predict
#output_type : {‘probability’, ‘margin’, ‘class’, ‘probability_vector’}, optional.
#Form of the predictions which are one of:
#‘probability’: Prediction probability associated with the True
#class (not applicable for multi-class classification)
print type(predictedProbability)
print predictedProbability
predictedProbability = list(predictedProbability)
# Out:
# <class 'graphlab.data_structures.sarray.SArray'>
# [0.7045905590057373, 0.5963408946990967, 0.44925159215927124, 0.6119099855422974]

# %% [markdown]
# **Quiz Question 2:** According to **model_5**, which loan is the least likely to be a safe loan?
#
# **Checkpoint:** Can you verify that for all the predictions with `probability >= 0.5`, the model predicted the label **+1**?

# %%
#print type(predictedProbability)
#convert to list for ease of working.
indexOfMin = predictedProbability.index(min(predictedProbability))
print "Minimum probability at position ", indexOfMin+1, " has probability =", predictedProbability[indexOfMin]
# Out:
# Minimum probability at position  3  has probability = 0.449251592159

# %% [markdown]
# ## Evaluating the model on the validation data

# %% [markdown]
# Recall that the accuracy is defined as follows:
# $$
# \mbox{accuracy} = \frac{\mbox{# correctly classified examples}}{\mbox{# total examples}}
# $$
#
# Evaluate the accuracy of the **model_5** on the **validation_data**.
#
# **Hint**: Use the `.evaluate()` method in the model.

# %%
#type(model_5) =  <class 'graphlab.toolkits.classifier.boosted_trees_classifier.BoostedTreesClassifier'>
#https://turi.com/products/create/docs/generated/graphlab.boosted_trees_classifier.BoostedTreesClassifier.evaluate.html#graphlab.boosted_trees_classifier.BoostedTreesClassifier.evaluate
#BoostedTreesClassifier.evaluate(model, *args, **kwargs)
evaluation = model_5.evaluate(validation_data)
print "type(evaluation) = ", type(evaluation)
print "evaluation['accuracy'] = ", round(evaluation['accuracy'], 2)
print "________________________________________________________"
print evaluation
print evaluation.keys()
# Out:
# type(evaluation) =  <type 'dict'>
# evaluation['accuracy'] =  0.67
# ________________________________________________________
# {'f1_score': 0.6715001599317625, 'auc': 0.7247215702188436, 'recall': 0.6827840416305291, 'precision': 0.6605831760016782, 'log_loss': 0.6176131769648966, 'roc_curve': Columns:
# 	threshold	float
# 	fpr	float
# 	tpr	float
# 	p	int
# 	n	int
#
# Rows: 100001
#
# Data:
# +-----------+-----+-----+------+------+
# | threshold | fpr | tpr |  p   |  n   |
# +-----------+-----+-----+------+------+
# |    0.0    | 1.0 | 1.0 | 4612 | 4672 |
# |   1e-05   | 1.0 | 1.0 | 4612 | 4672 |
# |   2e-05   | 1.0 | 1.0 | 4612 | 4672 |
# |   3e-05   | 1.0 | 1.0 | 4612 | 4672 |
# |   4e-05   | 1.0 | 1.0 | 4612 | 4672 |
# |   5e-05   | 1.0 | 1.0 | 4612 | 4672 |
# |   6e-05   | 1.0 | 1.0 | 4612 | 4672 |
# |   7e-05   | 1.0 | 1.0 | 4612 | 4672 |
# |   8e-05   | 1.0 | 1.0 | 4612 | 4672 |
# |   9e-05   | 1.0 | 1.0 | 4612 | 4672 |
# +-----------+-----+-----+------+------+
# ...

# %%
#+--------------+-----------------+  
#| target_label | predicted_label |  
#+--------------+-----------------+  
#|      -1      |        1        |false positive  
#|      -1      |        -1       |true negative  
#|      1       |        -1       |false negative  
#|      1       |        1        |true positive  
#+--------------+-----------------+

# %%
print "\nevaluation['confusion_matrix'] = \n", evaluation['confusion_matrix']
print type(evaluation['confusion_matrix'])
print evaluation['confusion_matrix'].column_names()
# Out:
# evaluation['confusion_matrix'] =
# +--------------+-----------------+-------+
# | target_label | predicted_label | count |
# +--------------+-----------------+-------+
# |      -1      |        1        |  1618 |
# |      -1      |        -1       |  3054 |
# |      1       |        -1       |  1463 |
# |      1       |        1        |  3149 |
# +--------------+-----------------+-------+
# [4 rows x 3 columns]
#
# <class 'graphlab.data_structures.sframe.SFrame'>
# ['target_label', 'predicted_label', 'count']

# %% [markdown]
# Calculate the number of **false positives** made by the model.

# %%
falsePositives = evaluation['confusion_matrix']['count'][0]
print "false positives = ", falsePositives
# Out:
# false positives =  1618

# %% [markdown]
# **Quiz Question 3**: What is the number of **false positives** on the **validation_data**?

# %% [markdown]
# Calculate the number of **false negatives** made by the model.

# %%
falseNegatives = evaluation['confusion_matrix']['count'][2]
print "false negatives = ", falseNegatives
# Out:
# false negatives =  1463

# %% [markdown]
# ## Comparison with decision trees
#
# In the earlier assignment, we saw that the prediction accuracy of the decision trees was around **0.64** (rounded). In this assignment, we saw that **model_5** has an accuracy of **0.67** (rounded).
#
# Here, we quantify the benefit of the extra 3% increase in accuracy of **model_5** in comparison with a single decision tree from the original decision tree assignment.
#
# As we explored in the earlier assignment, we calculated the cost of the mistakes made by the model. We again consider the same costs as follows:
#
# * **False negatives**: Assume a cost of \$10,000 per false negative.
# * **False positives**: Assume a cost of \$20,000 per false positive.
#
# Assume that the number of false positives and false negatives for the learned decision tree was
#
# * **False negatives**: 1936
# * **False positives**: 1503
#
# Using the costs defined above and the number of false positives and false negatives for the decision tree, we can calculate the total cost of the mistakes made by the decision tree model as follows:
#
# ```
# cost = $10,000 * 1936  + $20,000 * 1503 = $49,420,000
# ```
#
# The total cost of the mistakes of the model is $49.42M. That is a **lot of money**!.
#
# **Quiz Question 4**: Using the same costs of the false positives and false negatives, what is the cost of the mistakes made by the boosted tree model (**model_5**) as evaluated on the **validation_set**?

# %%
cost =  10000 * falseNegatives  + 20000 * falsePositives
print cost
print ("cost = ${:,.2f}".format(cost))
# Out:
# 46990000
# cost = $46,990,000.00

# %% [markdown]
# **Reminder**: Compare the cost of the mistakes made by the boosted trees model with the decision tree model. The extra 3% improvement in prediction accuracy can translate to several million dollars!  And, it was so easy to get by simply boosting our decision trees.

# %% [markdown]
# ## Most positive & negative loans.
#
# In this section, we will find the loans that are most likely to be predicted **safe**. We can do this in a few steps:
#
# * **Step 1**: Use the **model_5** (the model with 5 trees) and make **probability predictions** for all the loans in the **validation_data**.
# * **Step 2**: Similar to what we did in the very first assignment, add the probability predictions as a column called **predictions** into the validation_data.
# * **Step 3**: Sort the data (in decreasing order) by the probability predictions.
#
# Start here with **Step 1** & **Step 2**. Make predictions using **model_5** for examples in the **validation_data**. Use `output_type = probability`.

# %%
#recall - definition of model_5  
#model_5 = graphlab.boosted_trees_classifier.create(train_data,   
#                                                   validation_set=None,   
#                                                   target = target,   
#                                                   features = features,   
#                                                   max_iterations = 5)

# %%
predictedProbability = model_5.predict( validation_data, output_type='probability')
print predictedProbability.shape
print validation_data.shape
validation_data['predictions'] = predictedProbability
print validation_data.shape
# Out:
# (9284,)
# (9284, 26)
# (9284, 26)

# %% [markdown]
# **Checkpoint:** For each row, the probabilities should be a number in the range **[0, 1]**. We have provided a simple check here to make sure your answers are correct.

# %%
print "Your loans      : %s\n" % validation_data['predictions'].head(4)
print "Expected answer : %s" % [0.4492515948736132, 0.6119100103640573,
                                0.3835981314851436, 0.3693306705994325]
# Out:
# Your loans      : [0.44925159215927124, 0.6119099855422974, 0.38359811902046204, 0.3693307042121887]
#
# Expected answer : [0.4492515948736132, 0.6119100103640573, 0.3835981314851436, 0.3693306705994325]

# %% [markdown]
# Now, we are ready to go to **Step 3**. You can now use the `prediction` column to sort the loans in **validation_data** (in descending order) by prediction probability. Find the top 5 loans with the highest probability of being predicted as a **safe loan**.

# %%
print type(validation_data)
validation_data.sort('predictions', ascending=False).head(5)
# Out:
# <class 'graphlab.data_structures.sframe.SFrame'>
# Columns:
# 	safe_loans	int
# 	grade	str
# 	sub_grade_num	float
# 	short_emp	int
# 	emp_length_num	int
# 	home_ownership	str
# 	dti	float
# 	purpose	str
# 	payment_inc_ratio	float
# 	delinq_2yrs	int
# 	delinq_2yrs_zero	int
# 	inq_last_6mths	int
# 	last_delinq_none	int
# 	last_major_derog_none	int
# 	open_acc	int
# 	pub_rec	int
# 	pub_rec_zero	int
# 	revol_util	float
# 	total_rec_late_fee	float
# 	int_rate	float
# 	total_rec_int	float
# 	annual_inc	int
# 	funded_amnt	int
# 	funded_amnt_inv	int
# 	installment	float
# 	predictions	float
#
# Rows: 5
#
# Data:
# +------------+-------+---------------+-----------+----------------+----------------+
# | safe_loans | grade | sub_grade_num | short_emp | emp_length_num | home_ownership |
# +------------+-------+---------------+-----------+----------------+----------------+
# |     1      |   A   |      0.2      |     0     |       11       |    MORTGAGE    |
# ...

# %% [markdown]
# ** Quiz Question 5**: What grades are the top 5 loans?

# %%
#type(validation_data.sort('predictions', ascending=False).head(5)) #graphlab.data_structures.sframe.SFrame
validation_data.sort('predictions', ascending=False).head(5)['grade']
# Out:
# dtype: str
# Rows: 5
# ['A', 'A', 'A', 'A', 'A']

# %% [markdown]
# Let us repeat this excercise to find the top 5 loans (in the validation_data) with the lowest probability of being predicted as a safe loan:

# %%
validation_data.sort('predictions', ascending=True).head(5)['grade']
# Out:
# dtype: str
# Rows: 5
# ['D', 'C', 'B', 'C', 'C']

# %% [markdown]
# **Checkpoint:** You should expect to see 5 loans with the grade ['**D**', '**C**', '**C**', '**C**', '**B**'] or with ['**D**', '**C**', '**B**', '**C**', '**C**'].

# %% [markdown]
# ## Effect of adding more trees

# %% [markdown]
# In this assignment, we will train 5 different ensemble classifiers in the form of gradient boosted trees. We will train models with 10, 50, 100, 200, and 500 trees.  We use the **max_iterations** parameter in the boosted tree module.
#
# Let's get sarted with a model with **max_iterations = 10**:

# %%
start = time.time()
model_10 = graphlab.boosted_trees_classifier.create(train_data, 
                                                    validation_set=None, 
                                                    target = target, 
                                                    features = features, 
                                                    max_iterations = 10, 
                                                    verbose=False)
end = time.time()
print "time to predict = ", round(end-start, 4), " seconds"
# Out:
# time to predict =  0.968  seconds

# %% [markdown]
# Now, train 4 models with **max_iterations** to be:
# * `max_iterations = 50`,
# * `max_iterations = 100`
# * `max_iterations = 200`
# * `max_iterations = 500`.
#
# Let us call these models **model_50**, **model_100**, **model_200**, and **model_500**. You can pass in `verbose=False` in order to suppress the printed output.
#
# **Warning:** This could take a couple of minutes to run.

# %%
start = time.time()
model_50 = graphlab.boosted_trees_classifier.create(train_data, 
                                                    validation_set=None, 
                                                    target = target, 
                                                    features = features, 
                                                    max_iterations = 50, 
                                                    verbose=False)
end = time.time()
print "time to predict = ", round(end-start, 4), " seconds"
# Out:
# time to predict =  3.424  seconds

# %%
start = time.time()
model_100 = graphlab.boosted_trees_classifier.create(train_data, 
                                                    validation_set=None, 
                                                    target = target, 
                                                    features = features, 
                                                    max_iterations = 100, 
                                                    verbose=False)
end = time.time()
print "time to predict = ", round(end-start, 4), " seconds"
# Out:
# time to predict =  6.83  seconds

# %%
start = time.time()
model_200 = graphlab.boosted_trees_classifier.create(train_data, 
                                                    validation_set=None, 
                                                    target = target, 
                                                    features = features, 
                                                    max_iterations = 200, 
                                                    verbose=False)
end = time.time()
print "time to predict = ", round(end-start, 4), " seconds"
# Out:
# time to predict =  13.041  seconds

# %%
start = time.time()
model_500 = graphlab.boosted_trees_classifier.create(train_data, 
                                                    validation_set=None, 
                                                    target = target, 
                                                    features = features, 
                                                    max_iterations = 500, 
                                                    verbose=False)
end = time.time()
print "time to predict = ", round(end-start, 4), " seconds"
# Out:
# time to predict =  32.896  seconds

# %% [markdown]
# ## Compare accuracy on entire validation set

# %% [markdown]
# Now we will compare the predicitve accuracy of our models on the validation set. Evaluate the **accuracy** of the 10, 50, 100, 200, and 500 tree models on the **validation_data**. Use the `.evaluate` method.

# %%
print "start block"
model_accuracy = []
treeSize = [5, 10, 50, 100, 200, 500]#was just for comparison/experiment purposes.
model_accuracy.append(model_5.evaluate(validation_data)['accuracy'])
print "model_5.evaluate(validation_data)['accuracy'] = ", model_accuracy[0]
model_accuracy.append(model_10.evaluate(validation_data)['accuracy'])
print "model_10.evaluate(validation_data)['accuracy'] = ", model_accuracy[1]
model_accuracy.append(model_50.evaluate(validation_data)['accuracy'])
print "model_50.evaluate(validation_data)['accuracy'] = ", model_accuracy[2]
model_accuracy.append(model_100.evaluate(validation_data)['accuracy'])
print "model_100.evaluate(validation_data)['accuracy'] = ", model_accuracy[3]
model_accuracy.append(model_200.evaluate(validation_data)['accuracy'])
print "model_200.evaluate(validation_data)['accuracy'] = ", model_accuracy[4]
model_accuracy.append(model_500.evaluate(validation_data)['accuracy'])
print "model_500.evaluate(validation_data)['accuracy'] = ", model_accuracy[5]
print "--------------------------------------------------"
minIndex = model_accuracy.index(min(model_accuracy))
print "minimum accuracy = ", min(model_accuracy), " at index = ", minIndex, ", tree size = ", treeSize[minIndex]
maxIndex = model_accuracy.index(max(model_accuracy))
print "maximum accuracy = ", max(model_accuracy), " at index = ", maxIndex, ", tree size = ", treeSize[maxIndex]
# Out:
# start block
# model_5.evaluate(validation_data)['accuracy'] =  0.668138733305
# model_10.evaluate(validation_data)['accuracy'] =  0.672770357604
# model_50.evaluate(validation_data)['accuracy'] =  0.690758293839
# model_100.evaluate(validation_data)['accuracy'] =  0.691727703576
# model_200.evaluate(validation_data)['accuracy'] =  0.684510986644
# model_500.evaluate(validation_data)['accuracy'] =  0.671800947867
# --------------------------------------------------
# minimum accuracy =  0.668138733305  at index =  0 , tree size =  5
# maximum accuracy =  0.691727703576  at index =  3 , tree size =  100

# %% [markdown]
# **Quiz Question 6:** Which model has the **best** accuracy on the **validation_data**?

# %%
print "maximum accuracy = ", max(model_accuracy), " at index = ", maxIndex, ", tree size = ", treeSize[maxIndex]
# Out:
# maximum accuracy =  0.691727703576  at index =  3 , tree size =  100

# %% [markdown]
# **Quiz Question 7:** Is it always true that the model with the most trees will perform best on test data
#
# NO. results indicate an optimal tree size. Above or below the optimal tree size will have lower accuracy.

# %%
print "model_accuracy = \n", model_accuracy
print "treeSize = \n", treeSize
# Out:
# model_accuracy =
# [0.6907582938388626, 0.6917277035760449, 0.684510986643688, 0.6718009478672986]
# treeSize =
# [50, 100, 200, 500]

# %%
if len(model_accuracy)>4:
    print "deleting first element (cleanup)"
    model_accuracy.pop(0)#remove first element since we don't need it in subsequent analysis.
    treeSize.pop(0)
else:
    print "tree size=5 already deleted."
print "model_accuracy = ", model_accuracy
print "treeSize = ", treeSize
# Out:
# tree size=5 already deleted.
# model_accuracy =  [0.6907582938388626, 0.6917277035760449, 0.684510986643688, 0.6718009478672986]
# treeSize =  [50, 100, 200, 500]

# %% [markdown]
# ## Plot the training and validation error vs. number of trees

# %% [markdown]
# Recall from the lecture that the classification error is defined as
#
# $$
# \mbox{classification error} = 1 - \mbox{accuracy}
# $$
#
# In this section, we will plot the **training and validation errors versus the number of trees** to get a sense of how these models are performing. We will compare the 10, 50, 100, 200, and 500 tree models. You will need [matplotlib](http://matplotlib.org/downloads.html) in order to visualize the plots.
#
# First, make sure this block of code runs on your computer.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
def make_figure(dim, title, xlabel, ylabel, legend):
    plt.rcParams['figure.figsize'] = dim
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    if legend is not None:
        plt.legend(loc=legend, prop={'size':15})
    plt.rcParams.update({'font.size': 16})
    plt.tight_layout()

# %% [markdown]
# In order to plot the classification errors (on the **train_data** and **validation_data**) versus the number of trees, we will need lists of these accuracies, which we get by applying the method `.evaluate`.
#
# **Steps to follow:**
#
# * **Step 1:** Calculate the classification error for model on the training data (**train_data**).
# * **Step 2:** Store the training errors into a list (called `training_errors`) that looks like this:
# ```
# [train_err_10, train_err_50, ..., train_err_500]
# ```
# * **Step 3:** Calculate the classification error of each model on the validation data (**validation_data**).
# * **Step 4:** Store the validation classification error into a list (called `validation_errors`) that looks like this:
# ```
# [validation_err_10, validation_err_50, ..., validation_err_500]
# ```
# Once that has been completed, the rest of the code should be able to evaluate correctly and generate the plot.
#
#
# Let us start with **Step 1**. Write code to compute the classification error on the **train_data** for models **model_10**, **model_50**, **model_100**, **model_200**, and **model_500**.

# %%
#Step 1: Calculate the classification error for model on the training data (train_data)
# recall model_accuracy was created above on validation_data (not on train_data)
# NB: classification error=1−accuracy
training_errors = []
print "calculating classification errors on training data."
start = time.time()
training_errors.append(1-model_10.evaluate(train_data)['accuracy'])
training_errors.append(1-model_50.evaluate(train_data)['accuracy'])
training_errors.append(1-model_100.evaluate(train_data)['accuracy'])
training_errors.append(1-model_200.evaluate(train_data)['accuracy'])
training_errors.append(1-model_500.evaluate(train_data)['accuracy'])
print "classification error = 1−accuracy = training_errors = \n", training_errors
end = time.time()
print "time to predict = ", round(end-start, 4), " seconds"
# Out:
# calculating classification errors on training data.
# classification error = 1−accuracy = training_errors =
# [0.31174937531905744, 0.24605712136274482, 0.20043526155995595, 0.13643569144791634, 0.03823316048254921]
# time to predict =  4.082  seconds

# %%
#Step 2: Store the training errors into a list (called `training_errors`) that looks like this:
#[train_err_10, train_err_50, ..., train_err_500]
#completed in code above.

# %%
#Step 3: Calculate the classification error of each model on the validation data (validation_data).
validation_errors = []
print "calculating classification errors on validation data."
start = time.time()
validation_errors.append(1-model_10.evaluate(validation_data)['accuracy'])
validation_errors.append(1-model_50.evaluate(validation_data)['accuracy'])
validation_errors.append(1-model_100.evaluate(validation_data)['accuracy'])
validation_errors.append(1-model_200.evaluate(validation_data)['accuracy'])
validation_errors.append(1-model_500.evaluate(validation_data)['accuracy'])
print "classification error = 1−accuracy = validation_errors = \n", validation_errors
end = time.time()
print "time to predict = ", round(end-start, 4), " seconds"
# Out:
# calculating classification errors on validation data.
# classification error = 1−accuracy = validation_errors =
# [0.3272296423955192, 0.30924170616113744, 0.30827229642395515, 0.31548901335631196, 0.3281990521327014]
# time to predict =  1.414  seconds

# %%
#Step 4: Store the validation classification error into a list (called `validation_errors`) that looks like this:
#[validation_err_10, validation_err_50, ..., validation_err_500]
#done, see code block above.

# %% [markdown]
# Now, let us run **Step 2**. Save the training errors into a list called **training_errors**

# %%
#training_errors = [train_err_10, train_err_50, train_err_100, train_err_200, train_err_500]
#done, see code block above, written directly without intermediate variables.

# %% [markdown]
# Now, onto **Step 3**. Write code to compute the classification error on the **validation_data** for models **model_10**, **model_50**, **model_100**, **model_200**, and **model_500**.

# %%
#done see code block above.

# %% [markdown]
# Now, let us run **Step 4**. Save the training errors into a list called **validation_errors**

# %%
#validation_errors = [validation_err_10, validation_err_50, validation_err_100, validation_err_200, validation_err_500]
#done, see code block above.

# %% [markdown]
# Now, we will plot the **training_errors** and **validation_errors** versus the number of trees. We will compare the 10, 50, 100, 200, and 500 tree models. We provide some plotting code to visualize the plots within this notebook.
#
# Run the following code to visualize the plots.

# %%
print "training_errors = ", training_errors
print "validation_errors = ", validation_errors
plt.plot([10, 50, 100, 200, 500], training_errors, linewidth=4.0, label='Training error')
plt.plot([10, 50, 100, 200, 500], validation_errors, linewidth=4.0, label='Validation error')

make_figure(dim=(10,5), title='Error vs number of trees',
            xlabel='Number of trees',
            ylabel='Classification error',
            legend='best')
# Out:
# training_errors =  [0.31174937531905744, 0.24605712136274482, 0.20043526155995595, 0.13643569144791634, 0.03823316048254921]
# validation_errors =  [0.3272296423955192, 0.30924170616113744, 0.30827229642395515, 0.31548901335631196, 0.3281990521327014]

# %% [markdown]
# **Quiz Question 8**: Does the training error reduce as the number of trees increases?
# YES
#
# **Quiz Question 9**: Is it always true that the validation error will reduce as the number of trees increases?
# NO

# %% [markdown]
# quiz results = 100%
